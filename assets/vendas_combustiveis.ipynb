# %% [markdown]
# **Desafio técnico Raizen-analytics/data-engineering-test**

# %% [markdown]
# **Bibliotecas utilizadas para a análise**

# %%
import pandas as pd
import numpy as np

# %%
#!pip install xlrd
#!pip install openpyxl

# %% [markdown]
# **1. Vendas de Combustíveis Derivados de Petróleo por Unidade Federativa (UF) e Produto**

# %% [markdown]
# **Primeiramente foi analisada a planilha DPCache_m3, a planilha contém 4536 linhas de dados e 17 colunas**

# %%
dadosp2 = pd.read_excel('vendas_combustiveis.xlsx', engine="openpyxl", sheet_name='DPCache_m3')

# %%
dadosp2.head()
# Out:
#        COMBUSTÍVEL   ANO        REGIÃO    ESTADO         Jan        Fev  \
# 0  GASOLINA C (m3)  2000  REGIÃO NORTE  RONDÔNIA  136073.253   9563.263
# 1  GASOLINA C (m3)  2000  REGIÃO NORTE      ACRE    3358.346  40001.853
# 2  GASOLINA C (m3)  2000  REGIÃO NORTE  AMAZONAS   20766.918  21180.919
# 3  GASOLINA C (m3)  2000  REGIÃO NORTE   RORAIMA    3716.032   3200.400
# 4  GASOLINA C (m3)  2000  REGIÃO NORTE      PARÁ   29755.907  28661.951
#
#           Mar        Abr         Mai        Jun        Jul        Ago  \
# 0   11341.229   9369.746   10719.983  11165.968  12312.451  11220.970
# 1    3065.758   3495.290    2946.930   3023.920   3206.930   3612.580
# 2  242742.352  17615.604   20258.200  18741.344  19604.023  20221.674
# 3    3339.332  43338.929    3259.300   3636.216   3631.569   3348.416
# 4   28145.784  29294.796  359575.398  28830.479  32297.047  27310.979
#
#          Set        Out        Nov        Dez      TOTAL
# ...

# %%
dadosp2.shape
# Out:
# (4536, 17)

# %% [markdown]
# **Colunas da planilha DPCache_m3**

# %%
dadosp2.columns
# Out:
# Index(['COMBUSTÍVEL', 'ANO', 'REGIÃO', 'ESTADO', 'Jan', 'Fev', 'Mar', 'Abr',
#        'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'TOTAL'],
#       dtype='object')

# %% [markdown]
# **Tipos de combustíveis da planilha DPCache_m3**

# %%
dadosp2['COMBUSTÍVEL'].unique()
# Out:
# array(['GASOLINA C (m3)', 'GASOLINA DE AVIAÇÃO (m3)',
#        'QUEROSENE ILUMINANTE (m3)', 'QUEROSENE DE AVIAÇÃO (m3)',
#        'ÓLEO DIESEL (m3)', 'ÓLEO COMBUSTÍVEL (m3)',
#        'ETANOL HIDRATADO (m3)', 'GLP (m3)'], dtype=object)

# %% [markdown]
# **Anos da planilha DPCache_m3**

# %%
dadosp2['ANO'].unique()
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %% [markdown]
# **Agrupando a planilha DPCache_m3 por Ano, Estado (UF) e Combustível (Produto)**
#
# Pode-se observar o agrupamento da soma de vendas de produtos por cada ano de 2000 a 2020, por Unidade Federativa e por combustível (produto)

# %%
agrupamento1=dadosp2.groupby(['ANO','ESTADO', 'COMBUSTÍVEL']).sum()

# %%
agrupamento1.head(5)
# Out:
#                                                Jan           Fev          Mar  \
# ANO  ESTADO COMBUSTÍVEL
# 2000 ACRE   ETANOL HIDRATADO (m3)       676.230000    677.570000  1466.730000
#             GASOLINA C (m3)            3358.346000  40001.853000  3065.758000
#             GASOLINA DE AVIAÇÃO (m3)     30.300000     30.300000    60.600000
#             GLP (m3)                   2148.732727   2241.696364  2173.758182
#             QUEROSENE DE AVIAÇÃO (m3)  1154.561000   1250.719000   812.783000
#
#                                                Abr          Mai           Jun  \
# ANO  ESTADO COMBUSTÍVEL
# 2000 ACRE   ETANOL HIDRATADO (m3)       350.570000   450.580000    602.920000
#             GASOLINA C (m3)            3495.290000  2946.930000   3023.920000
#             GASOLINA DE AVIAÇÃO (m3)     30.160000    60.600000     77.687000
#             GLP (m3)                   2372.981818  2197.781818  26329.181818
# ...

# %% [markdown]
# **Agrupamento por ano e por produto com o somatório de todas as UFs juntas**
#
# Abaixo pode-se ver o agrupamento total das observações de dados por ano e pelo tipo de combustível da planilha DPCache_m3

# %%
agrupamento1_2 = dadosp2.groupby([dadosp2["ANO"], dadosp2["COMBUSTÍVEL"]])[['Jan', 'Fev', 'Mar', 'Abr','Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'TOTAL']].sum()

# %%
agrupamento1_2.head(15)
# Out:
#                                          Jan           Fev           Mar  \
# ANO  COMBUSTÍVEL
# 2000 ETANOL HIDRATADO (m3)      4.501529e+05  5.833285e+05  2.167973e+06
#      GASOLINA C (m3)            2.665000e+06  2.032035e+06  2.953926e+06
#      GASOLINA DE AVIAÇÃO (m3)   7.137909e+03  3.056356e+04  8.828282e+03
#      GLP (m3)                   2.230954e+06  1.375322e+06  1.414391e+06
#      QUEROSENE DE AVIAÇÃO (m3)  6.540386e+05  4.687403e+05  5.027201e+05
#      QUEROSENE ILUMINANTE (m3)  1.374207e+04  1.298646e+04  1.660551e+04
#      ÓLEO COMBUSTÍVEL (m3)      1.404970e+06  8.608004e+05  9.458631e+05
#      ÓLEO DIESEL (m3)           6.220375e+06  4.478046e+06  5.695769e+06
# 2001 ETANOL HIDRATADO (m3)      6.565610e+05  3.409123e+05  4.437686e+05
#      GASOLINA C (m3)            3.092129e+06  2.662320e+06  2.013468e+06
#      GASOLINA DE AVIAÇÃO (m3)   1.055658e+04  6.819099e+03  3.237762e+04
#      GLP (m3)                   1.592624e+06  2.188846e+06  1.361335e+06
# ...

# %% [markdown]
# **Analise da planilha DPCache_m3_2, a planilha contém 1080 linhas de dados e 17 colunas**

# %%
dadosp3 = pd.read_excel('vendas_combustiveis.xlsx', engine="openpyxl", sheet_name='DPCache_m3_2')

# %%
dadosp3.head()
# Out:
#              COMBUSTÍVEL   ANO        REGIÃO    ESTADO       Jan        Fev  \
# 0  ÓLEO DIESEL S-10 (m3)  2013  REGIÃO NORTE  RONDÔNIA  81453.67   3517.600
# 1  ÓLEO DIESEL S-10 (m3)  2013  REGIÃO NORTE      ACRE   1483.00  11202.000
# 2  ÓLEO DIESEL S-10 (m3)  2013  REGIÃO NORTE  AMAZONAS   6836.30   6784.232
# 3  ÓLEO DIESEL S-10 (m3)  2013  REGIÃO NORTE   RORAIMA   1475.30   1502.700
# 4  ÓLEO DIESEL S-10 (m3)  2013  REGIÃO NORTE      PARÁ  40913.48  45383.500
#
#          Mar        Abr         Mai      Jun       Jul      Ago       Set  \
# 0   3681.700   4700.670    5339.200   6166.4   6539.65   7283.7   8082.85
# 1    363.000    410.000     536.000    607.0    740.00    756.0    971.00
# 2  61443.832   3190.585    3305.000   3391.0   3637.00   4250.0   4576.00
# 3   1531.800  13423.700     795.400    757.2    939.80   1040.6    966.00
# 4  44013.219  41975.030  441140.785  30137.8  28146.30  31280.5  33033.05
#
#          Out        Nov       Dez      TOTAL
# ...

# %%
dadosp3.shape
# Out:
# (1080, 17)

# %% [markdown]
# **Colunas da planilha DPCache_m3_2**

# %%
dadosp3.columns
# Out:
# Index(['COMBUSTÍVEL', 'ANO', 'REGIÃO', 'ESTADO', 'Jan', 'Fev', 'Mar', 'Abr',
#        'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'TOTAL'],
#       dtype='object')

# %% [markdown]
# **Tipos de combustíveis da planilha DPCache_m3_2**

# %%
dadosp3['COMBUSTÍVEL'].unique()
# Out:
# array(['ÓLEO DIESEL S-10 (m3)', 'ÓLEO DIESEL S-500 (m3)',
#        'ÓLEO DIESEL S-1800 (m3)', 'ÓLEO DIESEL MARÍTIMO (m3)',
#        'ÓLEO DIESEL (OUTROS ) (m3)'], dtype=object)

# %% [markdown]
# **Anos da planilha DPCache_m3_2**

# %%
dadosp3['ANO'].unique()
# Out:
# array([2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %% [markdown]
# **Agrupando a planilha DPCache_m3_2 por Ano, Estado (UF) e Combustível (Produto)**
#
# Pode-se observar o agrupamento dos produtos por cada ano de 2013 a 2020, por Unidade Federativa e por combustível (produto)

# %%
agrupamento2=dadosp3.groupby(['ANO','ESTADO', 'COMBUSTÍVEL']).sum()

# %%
agrupamento2.head(5)
# Out:
#                                               Jan        Fev      Mar  \
# ANO  ESTADO COMBUSTÍVEL
# 2013 ACRE   ÓLEO DIESEL (OUTROS ) (m3)      0.000      0.000      0.0
#             ÓLEO DIESEL MARÍTIMO (m3)      25.000    109.000     40.0
#             ÓLEO DIESEL S-10 (m3)        1483.000  11202.000    363.0
#             ÓLEO DIESEL S-1800 (m3)     14139.166  12430.431  11134.0
#             ÓLEO DIESEL S-500 (m3)          0.000      0.000      0.0
#
#                                                Abr        Mai        Jun  \
# ANO  ESTADO COMBUSTÍVEL
# 2013 ACRE   ÓLEO DIESEL (OUTROS ) (m3)       0.000      0.000     91.000
#             ÓLEO DIESEL MARÍTIMO (m3)      119.730    801.730     32.000
#             ÓLEO DIESEL S-10 (m3)          410.000    536.000    607.000
#             ÓLEO DIESEL S-1800 (m3)     145268.893  10143.361  11170.935
#             ÓLEO DIESEL S-500 (m3)           0.000      0.000      0.000
#
# ...

# %% [markdown]
# **Agrupamento por ano e por produto com o somatório de todas as UFs juntas**
#
# Abaixo pode-se ver o agrupamento total das observações de dados por ano e pelo tipo de combustível da planilha DPCache_m3_2

# %%
agrupamento2_2 = dadosp3.groupby([dadosp3["ANO"], dadosp3["COMBUSTÍVEL"]])[['Jan', 'Fev', 'Mar', 'Abr','Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'TOTAL']].sum()

# %%
agrupamento2_2.head(15)
# Out:
#                                          Jan          Fev          Mar  \
# ANO  COMBUSTÍVEL
# 2013 ÓLEO DIESEL (OUTROS ) (m3)     6671.038     3167.741     3478.432
#      ÓLEO DIESEL MARÍTIMO (m3)     76539.717    63421.088    70690.371
#      ÓLEO DIESEL S-10 (m3)       1108467.539  1021294.741  1460507.966
#      ÓLEO DIESEL S-1800 (m3)     4028399.508  4293297.644  2933009.981
#      ÓLEO DIESEL S-500 (m3)      2800923.904  2437334.117  2469658.943
# 2014 ÓLEO DIESEL (OUTROS ) (m3)     3549.895    14253.244    13691.702
#      ÓLEO DIESEL MARÍTIMO (m3)    371468.335   109356.182    76561.917
#      ÓLEO DIESEL S-10 (m3)       1899909.546  2429165.925  1592928.387
#      ÓLEO DIESEL S-1800 (m3)      292636.351   104809.575    92504.240
#      ÓLEO DIESEL S-500 (m3)      8223741.197  5656564.333  6659685.756
# 2015 ÓLEO DIESEL (OUTROS ) (m3)     4908.974     2764.936     2211.094
#      ÓLEO DIESEL MARÍTIMO (m3)     87792.241    77293.893   201306.915
# ...

# %% [markdown]
# **Analise da planilha DPCache_m3_3, a planilha contém 594 linhas de dados e 17 colunas**

# %%
dadosp4 = pd.read_excel('vendas_combustiveis.xlsx', engine="openpyxl", sheet_name='DPCache_m3_3')

# %%
dadosp4.head()
# Out:
#           COMBUSTÍVEL   ANO        REGIÃO    ESTADO           Jan  \
# 0  GLP - Até P13 (m3)  2010  REGIÃO NORTE  RONDÔNIA  74941.911133
# 1  GLP - Até P13 (m3)  2010  REGIÃO NORTE      ACRE   2338.586957
# 2  GLP - Até P13 (m3)  2010  REGIÃO NORTE  AMAZONAS  10063.465580
# 3  GLP - Até P13 (m3)  2010  REGIÃO NORTE   RORAIMA   1440.769928
# 4  GLP - Até P13 (m3)  2010  REGIÃO NORTE      PARÁ  23198.949275
#
#             Fev            Mar           Abr            Mai           Jun  \
# 0   5455.704710    5766.664795   6847.914855    6263.050725   6207.913932
# 1  26436.096153    2017.396739   2255.280230    1987.722826   2530.503623
# 2  12184.039855  127965.213671  10277.273551    9198.853774  11620.947464
# 3   1427.807971    1560.257246  17292.607456    1312.856884   1238.323252
# 4  23417.893116   23220.213768  23579.445652  273654.002378  21263.215580
#
#             Jul           Ago           Set           Out           Nov  \
# ...

# %%
dadosp4.shape
# Out:
# (594, 17)

# %% [markdown]
# **Colunas da planilha DPCache_m3_3**

# %%
dadosp4.columns
# Out:
# Index(['COMBUSTÍVEL', 'ANO', 'REGIÃO', 'ESTADO', 'Jan', 'Fev', 'Mar', 'Abr',
#        'Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'TOTAL'],
#       dtype='object')

# %% [markdown]
# **Tipos de combustíveis da planilha DPCache_m3_3**

# %%
dadosp4['COMBUSTÍVEL'].unique()
# Out:
# array(['GLP - Até P13 (m3)', 'GLP - Outros (m3)'], dtype=object)

# %% [markdown]
# **Anos da planilha DPCache_m3_3**

# %%
dadosp4['ANO'].unique()
# Out:
# array([2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %% [markdown]
# **Agrupando a planilha DPCache_m3_3 por Ano, Estado (UF) e Combustível (Produto)**
#
# Pode-se observar o agrupamento dos produtos por cada ano de 2010 a 2020, por Unidade Federativa e por combustível (produto)

# %%
agrupamento3=dadosp4.groupby(['ANO','ESTADO', 'COMBUSTÍVEL']).sum()

# %%
agrupamento3.head(5)
# Out:
#                                            Jan           Fev           Mar  \
# ANO  ESTADO  COMBUSTÍVEL
# 2010 ACRE    GLP - Até P13 (m3)    2338.586957  26436.096153   2017.396739
#              GLP - Outros (m3)      106.983696    107.536232   1198.581522
#      ALAGOAS GLP - Até P13 (m3)  146976.435183  11340.938406  10476.881726
#              GLP - Outros (m3)      848.338768   7568.711957    529.659420
#      AMAPÁ   GLP - Até P13 (m3)    2261.777174   2136.416667   2400.438406
#
#                                           Abr           Mai           Jun  \
# ANO  ESTADO  COMBUSTÍVEL
# 2010 ACRE    GLP - Até P13 (m3)   2255.280230   1987.722826   2530.503623
#              GLP - Outros (m3)      85.248188     83.125000    104.266304
#      ALAGOAS GLP - Até P13 (m3)  11873.661232  11647.474638  11669.914312
#              GLP - Outros (m3)     430.815217    516.206522    448.795290
#      AMAPÁ   GLP - Até P13 (m3)   2023.416667   2337.221014  26325.206706
#
# ...

# %% [markdown]
# **Agrupamento por ano e por produto com o somatório de todas as UFs juntas**
#
# Abaixo pode-se ver o agrupamento total das observações de dados por ano e pelo tipo de combustível da planilha DPCache_m3_3

# %%
agrupamento3_2 = dadosp4.groupby([dadosp4["ANO"], dadosp4["COMBUSTÍVEL"]])[['Jan', 'Fev', 'Mar', 'Abr','Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'TOTAL']].sum()

# %%
agrupamento3_2.head(15)
# Out:
#                                   Jan           Fev           Mar  \
# ANO  COMBUSTÍVEL
# 2010 GLP - Até P13 (m3)  1.078603e+06  8.931407e+05  1.546384e+06
#      GLP - Outros (m3)   4.818204e+05  3.512830e+05  3.178644e+05
# 2011 GLP - Até P13 (m3)  1.105698e+06  1.519587e+06  1.103679e+06
#      GLP - Outros (m3)   3.308970e+05  3.481078e+05  5.096597e+05
# 2012 GLP - Até P13 (m3)  1.632839e+06  1.046275e+06  1.114855e+06
#      GLP - Outros (m3)   4.955852e+05  6.126962e+05  3.450038e+05
# 2013 GLP - Até P13 (m3)  1.489933e+06  1.155946e+06  1.661075e+06
#      GLP - Outros (m3)   1.659208e+06  6.834684e+05  5.175970e+05
# 2014 GLP - Até P13 (m3)  1.542087e+06  2.605885e+06  1.511320e+06
#      GLP - Outros (m3)   4.278744e+05  5.266712e+05  1.661275e+06
# 2015 GLP - Até P13 (m3)  1.724250e+06  1.268425e+06  1.544517e+06
#      GLP - Outros (m3)   4.496150e+05  6.715341e+05  3.960263e+05
# 2016 GLP - Até P13 (m3)  9.621741e+05  1.672436e+06  1.778269e+06
# ...

# %%
agrupamento3_2.shape
# Out:
# (22, 13)

# %% [markdown]
# **Concatenando o agrupamento das 3 planilhas por ano e produto, somando todas as UFs, em um único conjunto de dados**

# %%
a=agrupamento1_2.reset_index()
b = agrupamento2_2.reset_index()
c= agrupamento3_2.reset_index()

# %%
a.head()
# Out:
#     ANO                COMBUSTÍVEL           Jan           Fev           Mar  \
# 0  2000      ETANOL HIDRATADO (m3)  4.501529e+05  5.833285e+05  2.167973e+06
# 1  2000            GASOLINA C (m3)  2.665000e+06  2.032035e+06  2.953926e+06
# 2  2000   GASOLINA DE AVIAÇÃO (m3)  7.137909e+03  3.056356e+04  8.828282e+03
# 3  2000                   GLP (m3)  2.230954e+06  1.375322e+06  1.414391e+06
# 4  2000  QUEROSENE DE AVIAÇÃO (m3)  6.540386e+05  4.687403e+05  5.027201e+05
#
#             Abr          Mai           Jun           Jul           Ago  \
# 0  8.353446e+05   593678.364  6.418161e+05  4.972775e+05  5.002683e+05
# 1  4.063913e+06  2683043.499  3.654478e+06  8.770025e+06  3.489482e+06
# 2  9.102074e+03    13256.111  9.881747e+03  1.569995e+04  1.285821e+04
# 3  1.982593e+06  1434977.840  1.225386e+06  1.888598e+06  2.347165e+06
# 4  9.571307e+05  2182040.061  5.160926e+05  4.126257e+05  5.517583e+05
#
#             Set           Out           Nov           Dez         TOTAL
# ...

# %%
a.shape
# Out:
# (168, 15)

# %%
b.shape
# Out:
# (40, 15)

# %%
d=pd.concat([a,b,c], axis=0, ignore_index=True)

# %%
d.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# **Novo conjunto de dados feito com a concatenação dos agrupamentos**

# %%
d.head()
# Out:
#     ANO                COMBUSTÍVEL           Jan           Fev           Mar  \
# 0  2000      ETANOL HIDRATADO (m3)  4.501529e+05  5.833285e+05  2.167973e+06
# 1  2000            GASOLINA C (m3)  2.665000e+06  2.032035e+06  2.953926e+06
# 2  2000   GASOLINA DE AVIAÇÃO (m3)  7.137909e+03  3.056356e+04  8.828282e+03
# 3  2000                   GLP (m3)  2.230954e+06  1.375322e+06  1.414391e+06
# 4  2000  QUEROSENE DE AVIAÇÃO (m3)  6.540386e+05  4.687403e+05  5.027201e+05
#
#             Abr          Mai           Jun           Jul           Ago  \
# 0  8.353446e+05   593678.364  6.418161e+05  4.972775e+05  5.002683e+05
# 1  4.063913e+06  2683043.499  3.654478e+06  8.770025e+06  3.489482e+06
# 2  9.102074e+03    13256.111  9.881747e+03  1.569995e+04  1.285821e+04
# 3  1.982593e+06  1434977.840  1.225386e+06  1.888598e+06  2.347165e+06
# 4  9.571307e+05  2182040.061  5.160926e+05  4.126257e+05  5.517583e+05
#
#             Set           Out           Nov           Dez         TOTAL
# ...

# %%
d.shape
# Out:
# (230, 15)

# %% [markdown]
# **Mostrando o conjunto de dados agrupado por ano e combustível (produto)**
#
# Abaixo pode-se ver as primeiras 60 linhas do conjunto de dados

# %%
e = d.groupby([d["ANO"], d["COMBUSTÍVEL"]])[['Jan', 'Fev', 'Mar', 'Abr','Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'TOTAL']].sum()

# %%
e.head(60)
# Out:
#                                          Jan           Fev           Mar  \
# ANO  COMBUSTÍVEL
# 2000 ETANOL HIDRATADO (m3)      4.501529e+05  5.833285e+05  2.167973e+06
#      GASOLINA C (m3)            2.665000e+06  2.032035e+06  2.953926e+06
#      GASOLINA DE AVIAÇÃO (m3)   7.137909e+03  3.056356e+04  8.828282e+03
#      GLP (m3)                   2.230954e+06  1.375322e+06  1.414391e+06
#      QUEROSENE DE AVIAÇÃO (m3)  6.540386e+05  4.687403e+05  5.027201e+05
#      QUEROSENE ILUMINANTE (m3)  1.374207e+04  1.298646e+04  1.660551e+04
#      ÓLEO COMBUSTÍVEL (m3)      1.404970e+06  8.608004e+05  9.458631e+05
#      ÓLEO DIESEL (m3)           6.220375e+06  4.478046e+06  5.695769e+06
# 2001 ETANOL HIDRATADO (m3)      6.565610e+05  3.409123e+05  4.437686e+05
#      GASOLINA C (m3)            3.092129e+06  2.662320e+06  2.013468e+06
#      GASOLINA DE AVIAÇÃO (m3)   1.055658e+04  6.819099e+03  3.237762e+04
#      GLP (m3)                   1.592624e+06  2.188846e+06  1.361335e+06
# ...

# %% [markdown]
# **Abaixo pode-se ver as últimas 60 linhas do conjunto de dados**

# %%
e.tail(60)
# Out:
#                                           Jan           Fev           Mar  \
# ANO  COMBUSTÍVEL
# 2017 ETANOL HIDRATADO (m3)       1.207608e+06  1.220314e+06  1.542612e+06
#      GASOLINA C (m3)             8.328824e+06  5.008771e+06  4.899318e+06
#      GASOLINA DE AVIAÇÃO (m3)    4.824152e+03  6.018449e+03  8.446866e+03
#      GLP (m3)                    2.060009e+06  4.114812e+06  2.189470e+06
#      GLP - Até P13 (m3)          1.611043e+06  1.157874e+06  9.597837e+05
#      GLP - Outros (m3)           3.705233e+05  5.683445e+05  3.883366e+05
#      QUEROSENE DE AVIAÇÃO (m3)   6.383839e+05  8.599063e+05  1.055176e+06
#      QUEROSENE ILUMINANTE (m3)   7.773470e+02  5.856210e+02  1.712325e+03
#      ÓLEO COMBUSTÍVEL (m3)       3.368524e+05  4.122312e+05  2.835617e+05
#      ÓLEO DIESEL (OUTROS ) (m3)  2.466610e+03  2.192414e+03  2.604499e+03
#      ÓLEO DIESEL (m3)            1.100048e+07  7.381160e+06  6.707878e+06
# ...

# %%
e.shape
# Out:
# (230, 13)

# %% [markdown]
# **Agrupando o conjunto de dados concatenado com o somatório total de vendas de combustíveis em cada mês de cada ano de 2000 a 2020 e os respectivos totais anuais**

# %%
por_ano_combustivel= d.groupby([d["ANO"], d["COMBUSTÍVEL"]])[['Jan', 'Fev', 'Mar', 'Abr','Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'TOTAL']].sum().reset_index()

# %%
f= por_ano_combustivel.groupby([por_ano_combustivel["ANO"]])[['Jan', 'Fev', 'Mar', 'Abr','Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'TOTAL']].sum()

# %%
f
# Out:
#                Jan           Fev           Mar           Abr           Mai  \
# ANO
# 2000  1.364637e+07  9.841822e+06  1.370608e+07  1.346811e+07  1.370660e+07
# 2001  1.853120e+07  1.376793e+07  9.756567e+06  1.322115e+07  1.341948e+07
# 2002  1.121790e+07  1.852239e+07  1.375953e+07  9.766751e+06  1.336732e+07
# 2003  1.265756e+07  1.073606e+07  1.763635e+07  1.315239e+07  9.368968e+06
# 2004  1.560447e+07  1.324108e+07  1.115225e+07  1.854358e+07  1.384793e+07
# 2005  1.261595e+07  1.565201e+07  1.324192e+07  1.139077e+07  1.858985e+07
# 2006  1.211656e+07  1.283656e+07  1.595795e+07  1.363360e+07  1.154706e+07
# 2007  1.721390e+07  1.277396e+07  1.366311e+07  1.711134e+07  1.429104e+07
# 2008  1.503118e+07  1.819305e+07  1.361676e+07  1.519061e+07  1.826586e+07
# 2009  1.547539e+07  1.542920e+07  1.816018e+07  1.404094e+07  1.568725e+07
# 2010  2.047205e+07  1.786341e+07  1.841524e+07  2.181536e+07  1.725953e+07
# ...

# %% [markdown]
# **2. Vendas de Óleo Diesel por Unidade Federativa (UF) e Tipo**

# %% [markdown]
# **Investigando as 3 planilhas a fim de identificar quais possuem dados de venda de óleo diesel**

# %%
dadosp2['COMBUSTÍVEL'].unique()
# Out:
# array(['GASOLINA C (m3)', 'GASOLINA DE AVIAÇÃO (m3)',
#        'QUEROSENE ILUMINANTE (m3)', 'QUEROSENE DE AVIAÇÃO (m3)',
#        'ÓLEO DIESEL (m3)', 'ÓLEO COMBUSTÍVEL (m3)',
#        'ETANOL HIDRATADO (m3)', 'GLP (m3)'], dtype=object)

# %%
dadosp3['COMBUSTÍVEL'].unique()
# Out:
# array(['ÓLEO DIESEL S-10 (m3)', 'ÓLEO DIESEL S-500 (m3)',
#        'ÓLEO DIESEL S-1800 (m3)', 'ÓLEO DIESEL MARÍTIMO (m3)',
#        'ÓLEO DIESEL (OUTROS ) (m3)'], dtype=object)

# %%
dadosp4['COMBUSTÍVEL'].unique()
# Out:
# array(['GLP - Até P13 (m3)', 'GLP - Outros (m3)'], dtype=object)

# %% [markdown]
# **Agrupamento por ano e por tipo de combustível na planilha DPCache_m3_2, pois ela têm 5 tipos de óleo diesel**

# %%
agrupamento2_2 = dadosp3.groupby([dadosp3["ANO"], dadosp3["COMBUSTÍVEL"]])[['Jan', 'Fev', 'Mar', 'Abr','Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'TOTAL']].sum()

# %%
agrupamento2_2
# Out:
#                                           Jan           Fev           Mar  \
# ANO  COMBUSTÍVEL
# 2013 ÓLEO DIESEL (OUTROS ) (m3)  6.671038e+03  3.167741e+03  3.478432e+03
#      ÓLEO DIESEL MARÍTIMO (m3)   7.653972e+04  6.342109e+04  7.069037e+04
#      ÓLEO DIESEL S-10 (m3)       1.108468e+06  1.021295e+06  1.460508e+06
#      ÓLEO DIESEL S-1800 (m3)     4.028400e+06  4.293298e+06  2.933010e+06
#      ÓLEO DIESEL S-500 (m3)      2.800924e+06  2.437334e+06  2.469659e+06
# 2014 ÓLEO DIESEL (OUTROS ) (m3)  3.549895e+03  1.425324e+04  1.369170e+04
#      ÓLEO DIESEL MARÍTIMO (m3)   3.714683e+05  1.093562e+05  7.656192e+04
#      ÓLEO DIESEL S-10 (m3)       1.899910e+06  2.429166e+06  1.592928e+06
#      ÓLEO DIESEL S-1800 (m3)     2.926364e+05  1.048096e+05  9.250424e+04
#      ÓLEO DIESEL S-500 (m3)      8.223741e+06  5.656564e+06  6.659686e+06
# 2015 ÓLEO DIESEL (OUTROS ) (m3)  4.908974e+03  2.764936e+03  2.211094e+03
# ...

# %% [markdown]
# **Agrupando o total de vendas de óleo diesel, com o somatório dos tipos, por ano**
#
# Pode-se ver os totais de cada ano de 2013 a 2020 por mês e o total anual

# %%
oleo_tipo_por_ano = dadosp3.groupby([dadosp3["ANO"]])[['Jan', 'Fev', 'Mar', 'Abr','Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'TOTAL']].sum()

# %%
oleo_tipo_por_ano.shape
# Out:
# (8, 13)

# %%
oleo_tipo_por_ano
# Out:
#                Jan           Fev           Mar           Abr           Mai  \
# ANO
# 2013  8.021002e+06  7.818515e+06  6.937346e+06  8.141449e+06  9.221813e+06
# 2014  1.079131e+07  8.314149e+06  8.435372e+06  7.002385e+06  8.720958e+06
# 2015  8.721178e+06  1.128837e+07  8.130125e+06  1.001978e+07  1.441081e+07
# 2016  6.380399e+06  8.215138e+06  7.241040e+06  5.774094e+06  5.992688e+06
# 2017  9.867257e+06  1.367380e+07  9.772369e+06  7.675843e+06  7.730212e+06
# 2018  5.960489e+06  6.359818e+06  8.904577e+06  1.036988e+07  7.720173e+06
# 2019  8.042935e+06  7.598271e+06  7.213346e+06  8.901078e+06  7.230152e+06
# 2020  6.901254e+06  4.744264e+06  8.183724e+06  1.006563e+07  7.571697e+06
#
#                Jun           Jul           Ago           Set           Out  \
# ANO
# 2013  1.068028e+07  9.732656e+06  1.391075e+07  1.303868e+07  7.420718e+06
# 2014  8.819769e+06  6.421489e+06  6.333934e+06  9.056209e+06  1.229452e+07
# ...

# %% [markdown]
# **O somatório da tabela de tipos de óleo diesel da Plan1 só consta os dados da planilha DPCache_m3_2 do arquivo Excel, porém na planilha  DPCache_m3 também há registros de óleo diesel "ÓLEO DIESEL (m3)"**

# %%
dp2 = dadosp2[dadosp2["COMBUSTÍVEL"]=='ÓLEO DIESEL (m3)']

# %%
dp2.head(2)
# Out:
#            COMBUSTÍVEL   ANO        REGIÃO    ESTADO        Jan        Fev  \
# 2268  ÓLEO DIESEL (m3)  2000  REGIÃO NORTE  RONDÔNIA  64975.906  61739.210
# 2269  ÓLEO DIESEL (m3)  2000  REGIÃO NORTE      ACRE  17949.431  17466.252
#
#             Mar        Abr        Mai        Jun         Jul         Ago  \
# 2268  64759.399  61738.477  52986.687  52157.145  657895.696   47445.936
# 2269  19173.873  19504.944  19959.934  19348.662   18795.936  219041.256
#
#             Set        Out        Nov        Dez      TOTAL
# 2268  50347.051  34365.553  52298.993  57181.081  57900.258
# 2269  18025.337  18335.532  16654.477  15145.858  18681.020

# %% [markdown]
# **Agrupamento por ano do óleo diesel "ÓLEO DIESEL (m3)" em todos os anos de 2000 a 2020 e os totais anuais**

# %%
agrupamentodp2 = dp2.groupby([dp2["ANO"], dp2["COMBUSTÍVEL"]])[['Jan', 'Fev', 'Mar', 'Abr','Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'TOTAL']].sum()

# %%
agrupamentodp2
# Out:
#                                 Jan           Fev           Mar           Abr  \
# ANO  COMBUSTÍVEL
# 2000 ÓLEO DIESEL (m3)  6.220375e+06  4.478046e+06  5.695769e+06  4.028391e+06
# 2001 ÓLEO DIESEL (m3)  1.187571e+07  6.579828e+06  4.608636e+06  6.026032e+06
# 2002 ÓLEO DIESEL (m3)  5.183938e+06  1.207851e+07  6.777882e+06  4.841702e+06
# 2003 ÓLEO DIESEL (m3)  4.764209e+06  5.145002e+06  1.162542e+07  6.681000e+06
# 2004 ÓLEO DIESEL (m3)  7.963722e+06  5.069025e+06  5.288509e+06  1.218211e+07
# 2005 ÓLEO DIESEL (m3)  5.989020e+06  8.078808e+06  5.103937e+06  5.354756e+06
# 2006 ÓLEO DIESEL (m3)  3.705778e+06  5.840132e+06  8.206377e+06  5.282590e+06
# 2007 ÓLEO DIESEL (m3)  4.742166e+06  4.015701e+06  6.156760e+06  8.807376e+06
# 2008 ÓLEO DIESEL (m3)  6.607511e+06  5.184110e+06  4.226237e+06  6.848273e+06
# 2009 ÓLEO DIESEL (m3)  5.777614e+06  6.554142e+06  5.137822e+06  4.177565e+06
# 2010 ÓLEO DIESEL (m3)  5.513209e+06  6.388765e+06  7.333544e+06  5.650612e+06
# ...

# %%
agrupamentodp2_2 = dp2.groupby([dp2["ANO"]])[['Jan', 'Fev', 'Mar', 'Abr','Mai', 'Jun', 'Jul', 'Ago', 'Set', 'Out', 'Nov', 'Dez', 'TOTAL']].sum()

# %%
agrupamentodp2_2
# Out:
#                Jan           Fev           Mar           Abr           Mai  \
# ANO
# 2000  6.220375e+06  4.478046e+06  5.695769e+06  4.028391e+06  4.662529e+06
# 2001  1.187571e+07  6.579828e+06  4.608636e+06  6.026032e+06  4.226412e+06
# 2002  5.183938e+06  1.207851e+07  6.777882e+06  4.841702e+06  6.104273e+06
# 2003  4.764209e+06  5.145002e+06  1.162542e+07  6.681000e+06  4.710749e+06
# 2004  7.963722e+06  5.069025e+06  5.288509e+06  1.218211e+07  7.021026e+06
# 2005  5.989020e+06  8.078808e+06  5.103937e+06  5.354756e+06  1.213354e+07
# 2006  3.705778e+06  5.840132e+06  8.206377e+06  5.282590e+06  5.301998e+06
# 2007  4.742166e+06  4.015701e+06  6.156760e+06  8.807376e+06  5.586250e+06
# 2008  6.607511e+06  5.184110e+06  4.226237e+06  6.848273e+06  9.323834e+06
# 2009  5.777614e+06  6.554142e+06  5.137822e+06  4.177565e+06  6.798880e+06
# 2010  5.513209e+06  6.388765e+06  7.333544e+06  5.650612e+06  4.669568e+06
# ...
